# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.5.1.48-cp37-cp37m-win_amd64.whl (34.9 MB)
# Collecting numpy>=1.14.5
#   Using cached numpy-1.20.2-cp37-cp37m-win_amd64.whl (13.6 MB)
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-1.20.2 opencv-python-4.5.1.48

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['hello']
number_imgs = 10

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for hello
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Collecting pyqt5
#   Using cached PyQt5-5.15.4-cp36.cp37.cp38.cp39-none-win_amd64.whl (6.8 MB)
# Collecting lxml
#   Using cached lxml-4.6.3-cp37-cp37m-win_amd64.whl (3.5 MB)
# Collecting PyQt5-sip<13,>=12.8
#   Using cached PyQt5_sip-12.8.1-cp37-cp37m-win_amd64.whl (62 kB)
# Collecting PyQt5-Qt5>=5.15
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Installing collected packages: PyQt5-sip, PyQt5-Qt5, pyqt5, lxml
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.8.1 lxml-4.6.3 pyqt5-5.15.4

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.cf5ba28a-90f9-11eb-81c7-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.cf5ba28a-90f9-11eb-81c7-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d1c6219c-90f9-11eb-80f9-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d1c6219c-90f9-11eb-80f9-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d2fc8e34-90f9-11eb-9d8b-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d2fc8e34-90f9-11eb-9d8b-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d7d0020a-90f9-11eb-b0cb-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d7d0020a-90f9-11eb-b0cb-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d69b7194-90f9-11eb-bc4f-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d69b7194-90f9-11eb-bc4f-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d092a24c-90f9-11eb-9505-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d092a24c-90f9-11eb-9505-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d431c6ba-90f9-11eb-b5e4-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d431c6ba-90f9-11eb-b5e4-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d5665d92-90f9-11eb-8779-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d5665d92-90f9-11eb-8779-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.d906344a-90f9-11eb-9076-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.d906344a-90f9-11eb-9076-5cf3709bbcc6.xml
# Image:D:\YouTube\23-03-2021 - OD Full Course\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.da3bb8fe-90f9-11eb-aaa6-5cf3709bbcc6.jpg -> Annotation:D:/YouTube/23-03-2021 - OD Full Course/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.da3bb8fe-90f9-11eb-aaa6-5cf3709bbcc6.xml

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
